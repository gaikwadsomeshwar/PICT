# %%
#modules we will use
import numpy as np
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plot

#reading the data values
iris_data = pd.read_csv("Iris.csv")

# %%
#display first five columns
iris_data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#information of the dataset
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#missing values count in the dataset
missing_values_count = iris_data.isnull().sum()

missing_values_count
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
#Statistics of all columns
iris_data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#count of rows in each columns
iris_data.count()
# Out:
# Id               150
# SepalLengthCm    150
# SepalWidthCm     150
# PetalLengthCm    150
# PetalWidthCm     150
# Species          150
# dtype: int64

# %%
#max values in the dataset
iris_data.select_dtypes(include = ['int', 'float']).max()
# Out:
# Id               150.0
# SepalLengthCm      7.9
# SepalWidthCm       4.4
# PetalLengthCm      6.9
# PetalWidthCm       2.5
# dtype: float64

# %%
#min values in the dataset
iris_data.select_dtypes(include = ['int', 'float']).min()
# Out:
# Id               1.0
# SepalLengthCm    4.3
# SepalWidthCm     2.0
# PetalLengthCm    1.0
# PetalWidthCm     0.1
# dtype: float64

# %%
#mean of each column in the dataset
iris_data.select_dtypes(include = ['int', 'float']).mean()
# Out:
# Id               75.500000
# SepalLengthCm     5.843333
# SepalWidthCm      3.054000
# PetalLengthCm     3.758667
# PetalWidthCm      1.198667
# dtype: float64

# %%
#median of each column in the dataset
iris_data.select_dtypes(include = ['int', 'float']).median()
# Out:
# Id               75.50
# SepalLengthCm     5.80
# SepalWidthCm      3.00
# PetalLengthCm     4.35
# PetalWidthCm      1.30
# dtype: float64

# %%
#cumalitive sum in the dataset
iris_data.select_dtypes(include = 'float').cumsum()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1             10.0           6.5            2.8           0.4
# 2             14.7           9.7            4.1           0.6
# 3             19.3          12.8            5.6           0.8
# 4             24.3          16.4            7.0           1.0
# ..             ...           ...            ...           ...
# 145          851.6         446.2          543.1         171.8
# 146          857.9         448.7          548.1         173.7
# 147          864.4         451.7          553.3         175.7
# 148          870.6         455.1          558.7         178.0
# 149          876.5         458.1          563.8         179.8
#
# [150 rows x 4 columns]

# %%
#standard deviation in the dataset
iris_data.select_dtypes(include = ['int', 'float']).std()
# Out:
# Id               43.445368
# SepalLengthCm     0.828066
# SepalWidthCm      0.433594
# PetalLengthCm     1.764420
# PetalWidthCm      0.763161
# dtype: float64

# %%
#variance of each column in the dataset
iris_data.select_dtypes(include = ['int', 'float']).var()
# Out:
# Id               1887.500000
# SepalLengthCm       0.685694
# SepalWidthCm        0.188004
# PetalLengthCm       3.113179
# PetalWidthCm        0.582414
# dtype: float64

# %%
#Plotting the Data

# %%
iris_long = pd.melt(df, id_vars = 'Species')
ax = sbn.boxplot(x = "Species", y = "value", hue = "variable", data = iris_long)
plot.show()

# %%
iris_data['Species'].value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        50
# Name: Species, dtype: int64

# %%
iris_data['SepalLengthCm'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
iris_data['PetalLengthCm'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
plot.scatter(np.arange(150), iris_data['SepalWidthCm'])

# %%
plot.scatter(np.arange(150), iris_data['PetalWidthCm'])

# %%
iris_data.hist(bins = 5)
# Out:
# array([[<AxesSubplot:title={'center':'Id'}>,
#         <AxesSubplot:title={'center':'SepalLengthCm'}>],
#        [<AxesSubplot:title={'center':'SepalWidthCm'}>,
#         <AxesSubplot:title={'center':'PetalLengthCm'}>],
#        [<AxesSubplot:title={'center':'PetalWidthCm'}>, <AxesSubplot:>]],
#       dtype=object)
