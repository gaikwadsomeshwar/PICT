# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats.stats import pearsonr
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score
from sklearn.tree import DecisionTreeRegressor

# %matplotlib inline
# Suppress warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('titanic.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.countplot("Survived", data = data)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
fig, ax = plt.subplots(1, 2, figsize = (18, 8))
data["Sex"].value_counts().plot.bar(color = "skyblue", ax = ax[0])
ax[0].set_title("Number Of Passengers By Sex")
ax[0].set_ylabel("Population")
sns.countplot("Sex", hue = "Survived", data = data, ax = ax[1])
ax[1].set_title("Sex: Survived vs Dead")
plt.show()

# %%
sns.factorplot("Pclass", "Survived", hue = "Sex", data = data)
plt.show()

# %%
pd.crosstab([data["Sex"], data["Survived"]], data["Pclass"], 
            margins = True).style.background_gradient(cmap = "summer_r")
# Out:
# <style  type="text/css" >
# #T_a3cf19dc_4eb5_11eb_9338_acde48001122row0_col0,#T_a3cf19dc_4eb5_11eb_9338_acde48001122row0_col1,#T_a3cf19dc_4eb5_11eb_9338_acde48001122row0_col3,#T_a3cf19dc_4eb5_11eb_9338_acde48001122row3_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_a3cf19dc_4eb5_11eb_9338_acde48001122row0_col2,#T_a3cf19dc_4eb5_11eb_9338_acde48001122row1_col2{
#             background-color:  #f1f866;
#             color:  #000000;
#         }#T_a3cf19dc_4eb5_11eb_9338_acde48001122row1_col0{
#             background-color:  #96cb66;
#             color:  #000000;
#         }#T_a3cf19dc_4eb5_11eb_9338_acde48001122row1_col1{
#             background-color:  #a3d166;
#             color:  #000000;
#         }#T_a3cf19dc_4eb5_11eb_9338_acde48001122row1_col3{
#             background-color:  #cfe766;
#             color:  #000000;
#         }#T_a3cf19dc_4eb5_11eb_9338_acde48001122row2_col0{
#             background-color:  #a7d366;
# ...

# %%
fig, ax = plt.subplots(1, 2, figsize = (18, 8))
data["Pclass"].value_counts().plot.bar(color = "skyblue", ax = ax[0])
ax[0].set_title("Number Of Passengers By Pclass")
ax[0].set_ylabel("Population")
sns.countplot("Pclass", hue = "Survived", data = data, ax = ax[1])
ax[1].set_title("Pclass: Survived vs Dead")
plt.show()

# %%
sns.barplot(x = "Sex", y = "Survived", hue = "Pclass", data = data)
plt.show()

# %%
data["Embarked"] = data["Embarked"].fillna("S")
pd.crosstab([data["Embarked"], data["Survived"]], data["Sex"], 
            margins = True).style.background_gradient(cmap = "summer_r")
# Out:
# <style  type="text/css" >
# #T_3800ae86_4eb6_11eb_9338_acde48001122row0_col0,#T_3800ae86_4eb6_11eb_9338_acde48001122row2_col0,#T_3800ae86_4eb6_11eb_9338_acde48001122row3_col1,#T_3800ae86_4eb6_11eb_9338_acde48001122row3_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_3800ae86_4eb6_11eb_9338_acde48001122row0_col1{
#             background-color:  #e3f166;
#             color:  #000000;
#         }#T_3800ae86_4eb6_11eb_9338_acde48001122row0_col2{
#             background-color:  #f2f866;
#             color:  #000000;
#         }#T_3800ae86_4eb6_11eb_9338_acde48001122row1_col0{
#             background-color:  #d1e866;
#             color:  #000000;
#         }#T_3800ae86_4eb6_11eb_9338_acde48001122row1_col1{
#             background-color:  #f4fa66;
#             color:  #000000;
#         }#T_3800ae86_4eb6_11eb_9338_acde48001122row1_col2{
#             background-color:  #edf666;
#             color:  #000000;
# ...

# %%
fig, ax = plt.subplots(1, 2, figsize = (18, 8))
data["Embarked"].value_counts().plot.bar(color = "skyblue", ax = ax[0])
ax[0].set_title("Number Of Passengers By Embarked")
ax[0].set_ylabel("Number")
sns.countplot("Embarked", hue = "Survived", data = data, ax = ax[1])
ax[1].set_title("Embarked: Survived vs Unsurvived")
plt.show()

# %%
pd.crosstab([data["Embarked"], data["Survived"]], data["Pclass"], 
            margins = True).style.background_gradient(cmap = "summer_r")
# Out:
# <style  type="text/css" >
# #T_5db578a0_4eb6_11eb_9338_acde48001122row0_col0{
#             background-color:  #e2f066;
#             color:  #000000;
#         }#T_5db578a0_4eb6_11eb_9338_acde48001122row0_col1{
#             background-color:  #f6fa66;
#             color:  #000000;
#         }#T_5db578a0_4eb6_11eb_9338_acde48001122row0_col2{
#             background-color:  #f7fb66;
#             color:  #000000;
#         }#T_5db578a0_4eb6_11eb_9338_acde48001122row0_col3{
#             background-color:  #f2f866;
#             color:  #000000;
#         }#T_5db578a0_4eb6_11eb_9338_acde48001122row1_col0{
#             background-color:  #badc66;
#             color:  #000000;
#         }#T_5db578a0_4eb6_11eb_9338_acde48001122row1_col1{
#             background-color:  #f4fa66;
#             color:  #000000;
# ...

# %%
pd.crosstab([data["Pclass"], data["Survived"]], data["SibSp"], 
            margins = True).style.background_gradient(cmap = "summer_r")
# Out:
# <style  type="text/css" >
# #T_6f140404_4eb6_11eb_9338_acde48001122row0_col0{
#             background-color:  #fbfd66;
#             color:  #000000;
# ...

# %%
pd.crosstab([data["Pclass"], data["Survived"]], data["Parch"], 
            margins = True).style.background_gradient(cmap = "summer_r")
# Out:
# <style  type="text/css" >
# #T_80511d2e_4eb6_11eb_9338_acde48001122row0_col0,#T_80511d2e_4eb6_11eb_9338_acde48001122row0_col2{
#             background-color:  #f9fc66;
#             color:  #000000;
#         }#T_80511d2e_4eb6_11eb_9338_acde48001122row0_col1{
#             background-color:  #fbfd66;
#             color:  #000000;
# ...
