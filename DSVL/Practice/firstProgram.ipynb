# %%
print('Hello World')
# Out:
# Hello World

# %%
a = 10
b = 20
print(a + b)
# Out:
# 30

# %%
def sum(a, b, c):
  return a + b + c

# %%
sum(12, 13, 56)
# Out:
# 81

# %%
(a, b, c) = (23, 45, -90)
print(sum(a, b, c))
